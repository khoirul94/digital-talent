# %%
import pymysql
import pandas as pd

host = '127.0.0.1'
port = "3306"
user = 'root'
password = ''
database = 'classicmodels'

conn = pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df = pd.read_sql_query(sql,conn)
    return df

# %% [markdown]
# # 1. Prepare a list of offices sorted by country, state, city.

# %%
run("SELECT * FROM OFFICES ORDER BY COUNTRY")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 1          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 2          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 3          7         London  +44 20 7877 2041       25 Old Broad Street
# 4          1  San Francisco   +1 650 219 4782         100 Market Street
# 5          2         Boston   +1 215 837 0825          1550 Court Place
# 6          3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressLine2       state    country postalCode territory
# 0     Floor #2        None  Australia   NSW 2010      APAC
# 1         None        None     France      75017      EMEA
# 2         None  Chiyoda-Ku      Japan   102-8578     Japan
# 3      Level 7        None         UK   EC2N 1HN      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %%
run("SELECT * FROM OFFICES ORDER BY STATE")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 1          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 2          7         London  +44 20 7877 2041       25 Old Broad Street
# 3          1  San Francisco   +1 650 219 4782         100 Market Street
# 4          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 5          2         Boston   +1 215 837 0825          1550 Court Place
# 6          3            NYC   +1 212 555 3000      523 East 53rd Street
#
#   addressLine2       state    country postalCode territory
# 0         None        None     France      75017      EMEA
# 1     Floor #2        None  Australia   NSW 2010      APAC
# 2      Level 7        None         UK   EC2N 1HN      EMEA
# 3    Suite 300          CA        USA      94080        NA
# 4         None  Chiyoda-Ku      Japan   102-8578     Japan
# ...

# %%
run("SELECT * FROM OFFICES ORDER BY CITY ")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          2         Boston   +1 215 837 0825          1550 Court Place
# 1          7         London  +44 20 7877 2041       25 Old Broad Street
# 2          3            NYC   +1 212 555 3000      523 East 53rd Street
# 3          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4          1  San Francisco   +1 650 219 4782         100 Market Street
# 5          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 6          5          Tokyo   +81 33 224 5000               4-1 Kioicho
#
#   addressLine2       state    country postalCode territory
# 0    Suite 102          MA        USA      02107        NA
# 1      Level 7        None         UK   EC2N 1HN      EMEA
# 2      apt. 5A          NY        USA      10022        NA
# 3         None        None     France      75017      EMEA
# 4    Suite 300          CA        USA      94080        NA
# ...

# %% [markdown]
# # 2. How many employees are there in the company?

# %%
run("SELECT COUNT(*) AS TOTAL_EMPLOYEES from EMPLOYEES")
# Out:
#    TOTAL_EMPLOYEES
# 0               23

# %% [markdown]
# # 3. What is the total of payments received?

# %%
run("SELECT SUM(AMOUNT) AS TOTAL_PAYMENTS FROM PAYMENTS")
# Out:
#    TOTAL_PAYMENTS
# 0      8853839.23

# %% [markdown]
# # 4. List the product lines that contain 'Cars'.

# %%
run("SELECT * FROM PRODUCTLINES WHERE PRODUCTLINE LIKE '%CARS%'")
# Out:
#     productLine                                    textDescription  \
# 0  Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1  Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0            None  None
# 1            None  None

# %% [markdown]
# # 5. Report total payments for October 28, 2004.

# %%
run("SELECT paymentDate, SUM(AMOUNT) AS TOTAL_PAYMENTS FROM PAYMENTS WHERE PAYMENTDATE='2004-10-28'")
# Out:
#   paymentDate  TOTAL_PAYMENTS
# 0  2004-10-28        47411.33

# %% [markdown]
# # 6. Report those payments greater than \$100,000.

# %%
run("SELECT * FROM PAYMENTS WHERE AMOUNT>'100000'")
# Out:
#    customerNumber checkNumber paymentDate     amount
# 0             124    AE215433  2005-03-05  101244.59
# 1             124    KI131716  2003-08-15  111654.40
# 2             141     ID10962  2004-12-31  116208.40
# 3             141    JE105477  2005-03-18  120166.58
# 4             148    KM172879  2003-12-26  105743.00

# %% [markdown]
# # 7. List the products in each product line.

# %%
run("SELECT PRODUCTNAME, PRODUCTLINE FROM PRODUCTS ORDER BY PRODUCTLINE")
# Out:
#                                      PRODUCTNAME       PRODUCTLINE
# 0                       1952 Alpine Renault 1300      Classic Cars
# 1                            1972 Alfa Romeo GTA      Classic Cars
# 2                         1962 LanciaA Delta 16V      Classic Cars
# 3                              1968 Ford Mustang      Classic Cars
# 4                              2001 Ferrari Enzo      Classic Cars
# 5                             1969 Corvair Monza      Classic Cars
# 6                             1968 Dodge Charger      Classic Cars
# 7                               1969 Ford Falcon      Classic Cars
# 8                        1970 Plymouth Hemi Cuda      Classic Cars
# 9                             1969 Dodge Charger      Classic Cars
# 10                               1993 Mazda RX-7      Classic Cars
# 11                         1965 Aston Martin DB5      Classic Cars
# 12                   1948 Porsche 356-A Roadster      Classic Cars
# ...

# %% [markdown]
# # 8. How many products in each product line?

# %%
run("SELECT PRODUCTLINE, COUNT(PRODUCTNAME) AS TOTAL_PRODUCTS FROM PRODUCTS GROUP BY PRODUCTLINE")
# Out:
#         PRODUCTLINE  TOTAL_PRODUCTS
# 0      Classic Cars              38
# 1       Motorcycles              13
# 2            Planes              12
# 3             Ships               9
# 4            Trains               3
# 5  Trucks and Buses              11
# 6      Vintage Cars              24

# %% [markdown]
# # 9. What is the minimum payment received?

# %%
# run("SELECT * FROM PAYMENTS ORDER BY AMOUNT ASC")
run("SELECT MIN(AMOUNT) AS MINIMUM_PAYMENT FROM PAYMENTS")
# Out:
#    MINIMUM_PAYMENT
# 0           615.45

# %% [markdown]
# # 10. List all payments greater than twice the average payment.

# %%
run("""
SELECT *
FROM PAYMENTS 
WHERE 
    AMOUNT>(SELECT AVG(AMOUNT) FROM PAYMENTS)*2
""")
# Out:
#     customerNumber checkNumber paymentDate     amount
# 0              114    MA765515  2004-12-15   82261.22
# 1              124    AE215433  2005-03-05  101244.59
# 2              124    BG255406  2004-08-28   85410.87
# 3              124     ET64396  2005-04-16   83598.04
# 4              124    KI131716  2003-08-15  111654.40
# 5              141     ID10962  2004-12-31  116208.40
# 6              141    IN446258  2005-03-25   65071.26
# 7              141    JE105477  2005-03-18  120166.58
# 8              148    KM172879  2003-12-26  105743.00
# 9              167    GN228846  2003-12-03   85024.46
# 10             239    NQ865547  2004-03-15   80375.24
# 11             321     DJ15149  2003-11-03   85559.12
# 12             323    AL493079  2005-05-23   75020.13

# %% [markdown]
# # 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
run("""
    SELECT AVG(((MSRP-buyPrice)/buyPrice)*100) AS avgPercentageMarkup
    FROM
        products
""")
# Out:
#    avgPercentageMarkup
# 0            88.702392

# %% [markdown]
# # 12. How many distinct products does ClassicModels sell?

# %%
run("SELECT COUNT(DISTINCT productName) AS totalProducts FROM products")
# Out:
#    totalProducts
# 0            110

# %% [markdown]
# #  13. Report the name and city of customers who don't have sales representatives?

# %%
run("SELECT customerNumber, customerName, city, country, salesRepEmployeeNumber  FROM CUSTOMERS WHERE salesRepEmployeeNumber IS NULL")
# Out:
#     customerNumber                    customerName              city  \
# 0              125              Havel & Zbyszek Co          Warszawa
# 1              169               Porto Imports Co.            Lisboa
# 2              206      Asian Shopping Network, Co         Singapore
# 3              223                 Natürlich Autos         Cunewalde
# 4              237                   ANG Resellers            Madrid
# 5              247        Messner Shopping Network         Frankfurt
# 6              273               Franken Gifts, Co           München
# 7              293               BG&E Collectables          Fribourg
# 8              303                Schuyler Imports         Amsterdam
# 9              307                Der Hund Imports            Berlin
# 10             335       Cramer Spezialitäten, Ltd       Brandenburg
# 11             348           Asian Treasures, Inc.              Cork
# 12             356            SAR Distributors, Co          Hatfield
# ...

# %% [markdown]
# # 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.

# %%
run("""
    SELECT 
        CONCAT(firstName,' ',lastName) AS fullName, jobTitle 
    FROM 
        employees 
    WHERE 
        jobTitle LIKE '%MANAGER%' OR jobTitle LIKE '%VP%'
""")
# Out:
#             fullName              jobTitle
# 0     Mary Patterson              VP Sales
# 1      Jeff Firrelli          VP Marketing
# 2  William Patterson  Sales Manager (APAC)
# 3      Gerard Bondur   Sale Manager (EMEA)
# 4        Anthony Bow    Sales Manager (NA)

# %% [markdown]
# # 15. Which orders have a value greater than $5,000?

# %%
run("""
    SELECT orderNumber, SUM(quantityOrdered * priceEach) AS orderValue
    FROM
        orderdetails
    GROUP BY
        orderNumber
    HAVING
        orderValue > 5000
""")
# Out:
#      orderNumber  orderValue
# 0          10100    10223.83
# 1          10101    10549.01
# 2          10102     5494.78
# 3          10103    50218.95
# 4          10104    40206.20
# 5          10105    53959.21
# 6          10106    52151.81
# 7          10107    22292.62
# 8          10108    51001.22
# 9          10109    25833.14
# 10         10110    48425.69
# 11         10111    16537.85
# 12         10112     7674.94
# 13         10113    11044.30
# 14         10114    33383.14
# 15         10115    21665.98
# 16         10117    44380.15
# 17         10119    35826.33
# 18         10120    45864.03
# 19         10121    16700.47
# 20         10122    50824.66
# 21         10123    14571.44
# 22         10124    32641.98
# 23         10125     7565.08
# 24         10126    57131.92
# 25         10127    58841.35
# 26         10128    13884.99
# 27         10129    29429.14
# 28         10130     6036.96
# 29         10131    17032.29
# ..           ...         ...
# ...
